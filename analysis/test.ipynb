# %% [markdown]
# ## test1 semantic_similarity>0.94且fluency!=0

# %%
from gramformer import Gramformer
import pandas as pd

# %%
gf = Gramformer(models = 1, use_gpu=False) # 1=corrector, 2=detector
# Out:
# /home/liujunhui/miniconda3/envs/gec/lib/python3.10/site-packages/transformers/models/auto/tokenization_auto.py:796: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /home/liujunhui/miniconda3/envs/gec/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /home/liujunhui/miniconda3/envs/gec/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:471: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# ...

# %%
df = pd.read_excel("test.xlsx")
df['edits'] = ''
df.head(3)
# Out:
#                                             ori_text  \
# 0  We do n't usually study these subject very dee...
# 1  Although we do n't have good grades , we have ...
# 2  Young people nowdays do n't spend enough time ...
#
#                                             cor_text   fluency  toxicity  \
# 0  We don't usually study these subject very deeply.  0.616170  0.000001
# 1  Although we don't have good grades, we have ta...  0.487758 -0.000010
# 2  Young people nowdays don't spend enough time h...  0.440209 -0.000352
#
#    shannon_entropy  perplexity  semantic_entropy  semantic_similarity edits
# 0         0.025398    0.119179         -0.222749             0.971473
# 1         0.071903    0.346360         -0.575009             0.970110
# 2         0.026411    0.134976          0.281124             0.969678

# %%
for i,row in df.iterrows():

    ori_text=row['ori_text']
    cor_text=row['cor_text']

    edits=gf.get_edits(ori_text,cor_text)
    df.at[i, 'edits'] = edits

# %%
for i,row in df.iterrows():

    print(i)
    for item in row['edits']:
        print(item)

    print("++++++++++++++++++++++++++++++++++++++++++++++++++")
# Out:
# 0
# ('ORTH', "do n't", 1, 3, "don't", 1, 2)
# ('ORTH', 'deeply .', 8, 10, 'deeply.', 7, 8)
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# 1
# ('ORTH', "do n't", 2, 4, "don't", 2, 3)
# ('ORTH', 'grades ,', 6, 8, 'grades,', 5, 6)
# ('ORTH', 'things .', 13, 15, 'things.', 11, 12)
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# 2
# ('ORTH', "do n't", 3, 5, "don't", 3, 4)
# ('ORTH', 'communities .', 10, 12, 'communities.', 9, 10)
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# 3
# ('ORTH', "do n't", 2, 4, "don't", 2, 3)
# ('ORTH', 'grades ,', 6, 8, 'grades,', 5, 6)
# ('ORTH', 'things .', 13, 15, 'things.', 11, 12)
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# 4
# ('ORTH', "do n't", 3, 5, "don't", 3, 4)
# ('ORTH', 'communities .', 11, 13, 'communities.', 10, 11)
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# 5
# ('ORTH', 'example ,', 1, 3, 'example,', 1, 2)
# ('ORTH', 'jam ,', 6, 8, 'jam,', 5, 6)
# ('ORTH', "ca n't", 11, 13, "can't", 9, 10)
# ...

# %%
# 93
# 112
# 113
# 126
df.iloc[126]['ori_text']
# Out:
# 'Now a days all the up coming the graduates are just muddling the subject mostly 70 % of subject just learn .'

# %%
df.iloc[126]['cor_text']
# Out:
# 'Now a days all the upcoming the graduates are just muddling the subject mostly 70% of subject just learn.'

# %% [markdown]
# ## test2 semantic_similarity<0.94且fluency!=0

# %%
from gramformer import Gramformer
import pandas as pd

# %%
gf = Gramformer(models = 1, use_gpu=False) # 1=corrector, 2=detector
# Out:
# /home/liujunhui/miniconda3/envs/gec/lib/python3.10/site-packages/transformers/models/auto/tokenization_auto.py:796: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /home/liujunhui/miniconda3/envs/gec/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /home/liujunhui/miniconda3/envs/gec/lib/python3.10/site-packages/transformers/models/auto/auto_factory.py:471: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# ...

# %%
df = pd.read_excel("test2.xlsx")
df['edits'] = ''
df.head(3)
# Out:
#                                             ori_text  \
# 0                       SOME lucky POINTS , infall .
# 1  In the 2 1st century , yong people can learn a...
# 2  This will reduce the pollution caused by the c...
#
#                                             cor_text   fluency  toxicity  \
# 0                        SOME lucky POINTS, in fall.  0.132171 -0.000030
# 1  In the 21st century, yong people can learn a l...  0.676714  0.000002
# 2  This will reduce the pollution caused by the c... -0.003219  0.000005
#
#    shannon_entropy  perplexity  semantic_entropy  semantic_similarity edits
# 0         0.401071    1.179608          1.301758             0.722933
# 1         0.085899    0.438410         -1.575946             0.815622
# 2         0.138518    0.608593          0.015424             0.825421

# %%
for i,row in df.iterrows():

    ori_text=row['ori_text']
    cor_text=row['cor_text']

    edits=gf.get_edits(ori_text,cor_text)
    df.at[i, 'edits'] = edits

# %%
for i,row in df.iterrows():

    print(i)
    for item in row['edits']:
        print(item)

    print("++++++++++++++++++++++++++++++++++++++++++++++++++")
# Out:
# 0
# ('ORTH', 'POINTS , infall .', 2, 6, 'POINTS, in fall.', 2, 5)
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# 1
# ('ORTH', '2 1st century ,', 2, 6, '21st century,', 2, 4)
# ('ORTH', 'subjects .', 14, 16, 'subjects.', 12, 13)
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# 2
# ('ORTH', 'carbones', 8, 9, 'car bones', 8, 10)
# ('ORTH', 'cars .', 11, 13, 'cars.', 12, 13)
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# 3
# ('ORTH', '2 1st century ,', 2, 6, '21st century,', 2, 4)
# ('ORTH', 'subjects .', 14, 16, 'subjects.', 12, 13)
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# 4
# ('ORTH', '2 1st century ,', 2, 6, '21st century,', 2, 4)
# ('ORTH', 'subjects .', 15, 17, 'subjects.', 13, 14)
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# 5
# ('ORTH', '2 1st century ,', 2, 6, '21st century,', 2, 4)
# ('ORTH', 'subjects .', 15, 17, 'subjects.', 13, 14)
# ++++++++++++++++++++++++++++++++++++++++++++++++++
# 6
# ('ORTH', '2 1st ,', 2, 5, '21st,', 2, 3)
# ...

# %%
# 2
# 8
# 20
# 34
# 60
# 81
# 84
# 110
df.iloc[110]['ori_text']
# Out:
# 'According to me , in order to start a career with success it`s importand to have a solid base , that means knowledge and experience .'

# %%
df.iloc[110]['semantic_similarity']
# Out:
# np.float64(0.9368091821670532)
